# %%
import pandas as pd

# %%
# read the user-item csv
# spotify_playlist = pd.read_csv("spotify_dataset.csv",encoding = "utf-8",error_bad_lines = False)
# s = list(spotify_playlist.values)
# song_set = set()
# i = 0
# for d in s:
#     add_str = str(d[1]) + "|+|" + str(d[2])
#     i = i + 1
#     if i % 10000 == 0:
#         print(i)
#     song_set.add(add_str)
# song_set = list(song_set)
# song_as = []
# i = 0
# for d in song_set:
#     sd = d.split("|+|")
#     if len(sd) == 2:
#         song_as.append([sd[0],sd[1]])
#     else:
#         print("error")
#     i = i + 1
#     if i % 10000 == 0:
#         print(i)
# df = pd.DataFrame(song_as, columns=['Artist', 'Song'])
# df.to_csv("spotify_artist_song.csv",index=0)

# %%
spotify_as = pd.read_csv("spotify_artist_song.csv",encoding = "utf-8",error_bad_lines = False)

# %%
spotify_as = list(spotify_as.values)

# %%
import requests
import json
baseurl = "https://api.spotify.com/v1"

# %%
headers = {
    'Content-Type': 'application/json',
    'Authorization':'Bearer BQDF9I1sebQbwUiBBlpO8E5qAgQZ7yYWi_0iY1DKxZZYCGvnNdJ5WGgpjn5fq8K22GxjhpLDxFUyhEgNOkUSEtkiiUNPUL0z_k0hTmkbzG_U9laX91eqv3lkVTHZR5Dx7hVLx4h3_CBK-LZZOvLtZ9Ip7uLbo1MMUEamOP5EuZUKW31MBg',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36' 
}
# j = 0
# spotify_asi = []
for d in spotify_as[23332:]:
    artist = d[0]
    song = d[1]
    data = {"type":"track","limit":"10","q":song}
    response = json.loads(requests.get(baseurl + "/search",params=data, headers=headers).text)
    e_total = min(int(response["tracks"]["total"]),10)
#     print("etotal:" + str(e_total))
    if e_total <= 0:
        continue
#         print("not found in " + str(artist) + " " + str(song))
    else:
        flag = 0
        for i in range(e_total):
            e_song = response["tracks"]["items"][i]["name"]
            e_artist = response["tracks"]["items"][i]["artists"][0]["name"]
            e_id = response["tracks"]["items"][i]["id"]
            if e_song == song and e_artist == artist:
#                 print(i)
#                 print("found in " + str(artist) + " " + str(song))
                spotify_asi.append([artist,song,e_id])
                flag = 1
                break
#         if flag == 0:
#             print("not found in " + str(artist) + " " + str(song))
#     print("j:" + str(j))
    if j % 100 == 0:
        print("j:" + str(j))
    j = j + 1
# Out:
# j:23400
# j:23500
# j:23600
# j:23700
# j:23800
# j:23900
# j:24000
# j:24100
# j:24200
# j:24300
# j:24400
# j:24500
# j:24600
# j:24700
# j:24800
# j:24900
# j:25000
# j:25100
# j:25200
# j:25300
# j:25400
# j:25500
# j:25600
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-19-dff63fff1030> in <module>()
#      11     data = {"type":"track","limit":"10","q":song}
#      12     response = json.loads(requests.get(baseurl + "/search",params=data, headers=headers).text)
# ---> 13     e_total = min(int(response["tracks"]["total"]),10)
#      14 #     print("etotal:" + str(e_total))
#      15     if e_total <= 0:
#
# KeyError: 'tracks'

# %%
len(spotify_asi)
spotify_x = spotify_asi

# %%
headers = {
    'Content-Type': 'application/json',
    'Authorization':'Bearer BQDtSqhwIZrB5JedNpv8d37PsQOwSNBmDOE2rx8btPD7oOFjjGRQ7-NC3OnU-6lu9Xfif-qhaJq3MKVYJ36348dBObB_2myOgKffCHf1dbYbxAOxKO29EvWUvHSRD8aEBH7iNSbDzb29i4K01wbmYck2Ba4Wbpopja5r0qpD6Afd5xPzJA',
    'User-Agent': 'Mozilla/5.0 (Windows NT 6.1; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/73.0.3683.103 Safari/537.36' 
}
output_x = []
# artist song  id  key mode loudness danceability valence tempo instrumentalness liveness energy 
for i in range(len(spotify_x)):
    artist = spotify_x[i][0]
    song = spotify_x[i][1]
    sid = spotify_x[i][2]
    surl = baseurl + "/audio-features/" + str(sid)
    data = {}
    response = json.loads(requests.get(surl,params=data, headers=headers).text)
    print(sid)
    if "error" in response:
        continue
    temp = [artist,song, sid, response["key"], response["mode"],response["loudness"], 
            response["danceability"],response["valence"],response["tempo"], response["instrumentalness"], response["liveness"], response["energy"]]
    output_x.append(temp)
    print(i)
# Out:
# 6dDAEBJGbFdN1ykSjeqzDV
# 0
# 5mgBfx8KgHUWB0q3gGUx5d
# 1
# 3FskvRCO2wyG5t1Ma94NaZ
# 2
# 1PwsDNCoodF3Jglf6adGZT
# 3
# 0JBPzw7WBeRFcEcBVCYqVc
# 4
# 5kEPBRWPA7iV6g55T1qOoD
# 5
# 1j87BDihMM04v4Hjq6I8JU
# 6
# 4nJGiV2JJbFgv1P50ehGz9
# 7
# 6NeonJ5xfE4NDJ5TVenjSZ
# 8
# 4Cp435Voyo8XWQSkuVAzy6
# 9
# 1SxlfgYoj0uJNYW081nWiJ
# 10
# 3ROjRfD9HCX4rmuOfoEpwO
# 11
# 2bztwuqlc1u2mlzqMcM0kf
# 12
# 564uCZRoVHp2MK8ewLR2SC
# 13
# 4y6jKTMU028Szn8LYUrTst
# 14
# 5s70o3UZixHh3k3AdyStCy
# 15
# 6glt32nbITTGWpOdARlEIy
# 16
# 1SC45Nb6aE0yDKLIcIAS6x
# 17
# 0jqcKVUIBYeUNStVapgbCT
# 18
# 4NxFpSewmN8rVgnq9pv50X
# 19
# 6SXy02aTZU3ysoGUixYCz0
# 20
# 1rQo5PQuzjvhDENtxnx3ny
# 21
# 6duItudYmcRd96l45PoKNl
# 22
# 4rQqT8I2pu0AZHFUV1PVq0
# 23
# 3bL3Q7RPzST59rgRLo7koY
# 24
# 5AyO347D3sql01aUNiokW4
# 25
# 4tg1dZ2NtMIswI9qnrv7WN
# 26
# 5xFWALIGrLLbYzUS3BhKuA
# 27
# 4od10a8WsHVPCSr5qLxF8Y
# 28
# 1VDUqm8tTdXyIjB67A2V46
# 29
# 5GupTAKmTOxEaEOBdpv2Um
# 30
# 0TBlVhJEudNXpbVF0gI4Ar
# 31
# 3XGCYDNtugVUhb6ipR47lM
# 32
# ...

# %%
df = pd.DataFrame(output_x, columns=["artist","song","id","key","mode","loudness", "danceability",
                                     "valence","tempo","instrumentalness","liveness","energy"])
df.to_csv("spotify_9000.csv",index=0)
# Out:
# ['The Doors',
#  'Close To You - Live At The Aquarius - The Second Performance LP Version',
#  '6dDAEBJGbFdN1ykSjeqzDV',
#  7,
#  1,
#  -19.108,
#  0.639,
#  0.574,
#  116.339,
#  0.000463,
#  0.695,
#  0.277]
